# %% [markdown]
# <a href="https://colab.research.google.com/github/AkilaIsuri/HVAC-Anomaly-Detection-Model/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import libraries
#Numpy and pandas for data manipulation and numerical calculations
#matplotlib and seaborn for data visualizations
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('data set.csv', delimiter = ';')
print(data.head())
# Out:
#                    Timestamp   T_Supply   T_Return  SP_Return  T_Saturation  \
# 0  2019-10-15 00:00:00+02:00  19.859999  20.469999       18.5         19.02
# 1  2019-10-15 00:15:00+02:00  19.855000  20.430000       18.5         19.02
# 2  2019-10-15 00:30:00+02:00  19.850000  20.410000       18.5         19.02
# 3  2019-10-15 00:45:00+02:00  19.840000  20.379999       18.5         19.08
# 4  2019-10-15 01:00:00+02:00  19.830000  20.350000       18.5         19.08
#
#    T_Outdoor  RH_Supply  RH_Return  RH_Outdoor  Energy  Power
# 0  20.299999  71.110001  58.919998        79.5     0.0    0.0
# 1  20.299999  71.320000  59.000000        82.0     0.0    0.0
# 2  20.299999  71.470001  59.109997        79.5     0.0    0.0
# 3  20.299999  71.439995  59.309998        77.0     0.0    0.0
# 4  20.299999  71.580002  59.559998        79.5     0.0    0.0

# %%
#Printing number of rows and features
print(data.shape)
# Out:
# (33888, 11)

# %%
#To generate descriptive statistics
print(data.describe())
# Out:
#            T_Supply      T_Return     SP_Return  T_Saturation     T_Outdoor  \
# count  33888.000000  33888.000000  33888.000000  33888.000000  33888.000000
# mean      20.436936     19.994425     22.302290     18.580051     12.414164
# std        3.535683      2.357756      0.745301      2.237516      4.925918
# min       12.264999     12.344999     18.500000     12.300000      2.300000
# 25%       17.879999     18.389999     22.500000     17.260000      8.900000
# 50%       19.785000     20.385000     22.500000     18.059999     11.800000
# 75%       23.256249     21.699999     22.500000     20.180000     15.300000
# max       30.295000     25.990000     23.500000     26.400000     32.799999
#
#           RH_Supply     RH_Return    RH_Outdoor        Energy         Power
# count  33888.000000  33888.000000  33888.000000  33888.000000  33888.000000
# mean      45.433972     37.251636     73.803308      5.769196      2.308225
# ...

# %%
#Give the missing values
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33888 entries, 0 to 33887
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Timestamp     33888 non-null  object
#  1   T_Supply      33888 non-null  float64
#  2   T_Return      33888 non-null  float64
#  3   SP_Return     33888 non-null  float64
#  4   T_Saturation  33888 non-null  float64
#  5   T_Outdoor     33888 non-null  float64
#  6   RH_Supply     33888 non-null  float64
#  7   RH_Return     33888 non-null  float64
#  8   RH_Outdoor    33888 non-null  float64
#  9   Energy        33888 non-null  float64
#  10  Power         33888 non-null  float64
# dtypes: float64(10), object(1)
# memory usage: 2.8+ MB
# None

# %%
#Give the number of missing records in each column
print(data.isnull().sum())
# Out:
# Timestamp       0
# T_Supply        0
# T_Return        0
# SP_Return       0
# T_Saturation    0
# T_Outdoor       0
# RH_Supply       0
# RH_Return       0
# RH_Outdoor      0
# Energy          0
# Power           0
# dtype: int64

# %%
#Before performing EDA, seperating Numerical and categorical variables for easy analysis.
cat_cols = data.select_dtypes(include =['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical variables:")
print(cat_cols)
print("Numerical variables:")
print(num_cols)
# Out:
# Categorical variables:
# Index(['Timestamp'], dtype='object')
# Numerical variables:
# ['T_Supply', 'T_Return', 'SP_Return', 'T_Saturation', 'T_Outdoor', 'RH_Supply', 'RH_Return', 'RH_Outdoor', 'Energy', 'Power']

# %%
#Visualizing the dataset by taking one variable at a time
for col in num_cols:
  print(col)
  print('Skew :', round(data[col].skew(),2))
  plt.figure(figsize=(15,4))
  plt.subplot(1,2,1)
  data[col].hist(grid=False)
  plt.ylabel('count')
  plt.subplot(1,2,2)
  sns.boxplot(x=data[col])
  plt.show()
# Out:
# T_Supply
# Skew : 0.44
# T_Return
# Skew : -0.55
# SP_Return
# Skew : -2.81
# T_Saturation
# Skew : 0.26
# T_Outdoor
# Skew : 0.88
# RH_Supply
# Skew : 0.68
# RH_Return
# Skew : 0.69
# RH_Outdoor
# Skew : -0.74
# Energy
# Skew : 0.18
# Power
# Skew : 0.16

# %%
#A pair plot can be used to show the correlation between two variables
plt.figure(figsize=(13,17))
sns.pairplot(data)
plt.show()

# %%
# !git clone <https://github.com/AkilaIsuri/HVAC-Anomaly-Detection-Model.git>
# !git add .
# !git commit -m "Your commit message"
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `git clone <https://github.com/AkilaIsuri/HVAC-Anomaly-Detection-Model.git>'
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push origin <main>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `git push origin <main>'
